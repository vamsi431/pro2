# %%
import pandas as pd

# %% [markdown]
# here we are importing the pandas library

# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
res=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(res.content,'lxml')
table=soup.find_all('table')[0]
df=pd.read_html(str(table))[0]
postalcode=df["Postal Code"].tolist()
brought=df["Borough"].tolist()
neighberhood=df["Neighborhood"].tolist()

# %% [markdown]
# first we are importing the requests
# then we are importing the Beautifulsoup from bs4
# importing tabulate from the tabulate
# now assigning res with data from the wikipedia using the get function
# allocating the soup with res content and in lxml fromat lxml
# assigning table with soup method with table
# allocating a dataframe name and reading the html into it
# now we are crreating the rows with requested names

# %%
rrr=zip(postalcode,brought,neighberhood)
df_rows=pd.DataFrame(rrr,columns=('Postal Code','Borough','Neighborhood'))

# %% [markdown]
# assigning the dataframe with the zip with requested columns names
# now we are creating a new dataframe name with pandas

# %%
df_rows
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 7           M8A      Not assigned
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 10          M2B      Not assigned
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 15          M7B      Not assigned
# 16          M8B      Not assigned
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 19          M2C      Not assigned
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 24          M7C      Not assigned
# 25          M8C      Not assigned
# ...

# %% [markdown]
# these are the resulting dataframe of after scraping

# %%
df_final=df_row[df_row.Borough!="Not assigned"].reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f28f8a4ae24c> in <module>
# ----> 1 df_final=df_row[df_row.Borough!="Not assigned"].reset_index(drop=True)
#
# NameError: name 'df_row' is not defined

# %% [markdown]
# now we are avoiding the borough with not assigned

# %%
df_final

# %% [markdown]
# this is our final result

# %%
df_final.shape[0]

# %% [markdown]
# rows in the data frame

# %%
geo_data = pd.read_csv("http://cocl.us/Geospatial_data")
geo_data

# %% [markdown]
# the latitude ans longitude of respective postal codes

# %%
df = pd.merge(df_final, geo_data, how='inner', on='Postal Code')

# %%
df

# %% [markdown]
# in this the postal with there respective latitude and longitude are maped

# %%
neighborhoods =  df[df['Borough'].str.contains("Toronto")].reset_index(drop='true')
neighborhoods

# %%
from geopy.geocoders import Nominatim
# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode('Toronto')
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))

# create map of Toronto using latitude and longitude values
map_T = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, postal_code in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Postal Code']):
    label = '{}, {}'.format(postal_code, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_T)  
    
map_T
